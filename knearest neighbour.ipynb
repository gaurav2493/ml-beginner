# %%
from sklearn import tree
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
iris = datasets.load_iris()
xTrain, xTest, yTrain, yTest = train_test_split(iris.data, iris.target, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(3, weights='uniform')
clf.fit(xTrain, yTrain)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
pred = clf.predict(xTest)

# %%
plt.hist(xTrain)
# Out:
# (array([[ 0.,  0.,  0.,  0.,  0.,  7., 29., 30., 24., 10.],
#         [ 0.,  0.,  7., 59., 31.,  3.,  0.,  0.,  0.,  0.],
#         [ 0., 26.,  5.,  1.,  5., 23., 21., 15.,  4.,  0.],
#         [31., 36., 28.,  5.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([0.1 , 0.86, 1.62, 2.38, 3.14, 3.9 , 4.66, 5.42, 6.18, 6.94, 7.7 ]),
#  <a list of 4 BarContainer objects>)
